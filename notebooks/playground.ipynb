# %%
print("Hello World")
# Out:
# Hello World

# %%
  lis = [1, 2, 3, 4, 5, 6, 7, 8, 9]
  lis
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
print(lis)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import numpy as np

# %%
l = np.linspace(0, 10, 5)

# %%
l
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
import matplotlib as plt

# %%
x = np.array([2,4,6,8,10])
y = np.linspace(0, 10, 20)
print("x_values:", x,)
# Out:
# x_values: [ 2  4  6  8 10]

# %%
plt.p
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 plt.scatter(x, y)
#
# File c:\Users\midef\Desktop\Tutorials\Python Practice\.venv\Lib\site-packages\matplotlib\_api\__init__.py:318, in caching_module_getattr.<locals>.__getattr__(name)
#     316 if name in props:
#     317     return props[name].__get__(instance)
# --> 318 raise AttributeError(
#     319     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'scatter'

# %%
import pandas as pd
import numpy as np
# Load Dataset
df = pd.read_csv("Heart_Disease_Prediction.csv")

print(df.head())

print("\nShape")
print(df.shape)
# Out:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# 2                        0         7      Presence
# 3                        1         7       Absence
# 4                        1         3       Absence
#
# Shape
# (270, 14)
